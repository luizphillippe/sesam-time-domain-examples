# %% [markdown]
# ## Description

# %% [markdown]
# This Jupyter notebook is part of the "Buckling Analysis of EMULF Delta Floater using the Time Domain Response Reconstruction Method" tutorial. In the previous steps of this tutorial the user is assumed to have exported a structural and a capacity model from GeniE, as well as panel models and wadam input files from HydroD. After these, a few steps are necessary in HydroD and Sima/Bladed (Sima is assumed in this tutorial). Those steps are not part of this tutorial and can be skipped as the resulting input files are provided.
#
# In this notebook Python is used with OneWorkflow to set up a Sesam Time Domain Response Reconstruction workflow for buckling check according to DNV-RP-C201. This workflow consists of a precomputation step, which is done once, and a reconstruction step, which is done for each design load case (DLC).
#
# In the precomputation step, Sesam Core is used to generate unit responses of the structure associated with unit loads, unit motions, and unit waves, accounting for mooring/tower/Morison forces, and radiated and diffracted hydrodynamic pressure, respectively. Sesam Core in this case runs Wadam and Sestra in the background.
#
# In the reconstruction step, and following a coupled analysis (computing forces and motions) in Sima, the local structure response is directly reconstructed using the precomputed unit reponses in combination with the coupled analysis results.
#
# As there is no need to generate new loads or perform structural analysis for each new design load case, the method is orders-of-magnitude faster than a standard time domain method.
#
# The capacity model comes as a single JSON file from GeniE, control data is read from a spreadsheet into a dictionary (Python), including file names for coupled analysis result.
#
# <img src="EMULF_Deltafloater.png" alt="Drawing" style="width: 700px;"/>
#
# Results are currently stored in one .csv and one .lis file for each stiffened plate group.
# Buckling results are presented as a table of worst usage factor over all time steps and load cases for each stiffened plate group. Note that the first two time steps are ignored, to avoid unrealistic result peaks.
#
# The workflow is split into several cells which quickly summarize the procedure:
#
# - Set up files and folders for the workflow
# - Precompute
# - Read DLCs from a spreadsheet
# - Create tasks for each DLC
# - Run the analysis
# - Buckling results agreggation over all DLCs

# %% [markdown]
# ## Set up files and folders for the workflow

# %% [markdown]
# Some general workflow properties are setup and the OneWorkflow client is created. The client will be important to manage and execute the workflow.

# %%
from pathlib import Path
import os, sys
from dnv.oneworkflow.utils import *


####### USER INPUT #########

workspaceId = "FOWT_ULS"                    # Set the Id for the workspace
cloudRun = False                            # Set whether to run in the cloud ( in this example set to False)
topsuper = 3                                # superelement type number for the structural model
model_prefix =""                            # prefix for the structural model

#### END of USER INPUT ####


root_folder = os.getcwd()                                   #The root folder is set as the path to the current working directory of the notebook. 
workspacePath = str(Path(root_folder, 'Workspace'))         #The workspace path is set to a subfolder "Workspace" inside the root folder
sys.path.append(os.path.join(root_folder, '..\\..\\PythonModules'))  # Path to PythonModules

# %% [markdown]
# Related to the folders defined above, it is assumed in the code that common input files for the workflow are gathered in a folder "CommonFiles" inside the workspace path. If you have not yet, please copy the folder "CommonFiles" from the input files of this tutorial inside the "Workspace" folder.

# %% [markdown]
# ## Precompute
# Sesam Core runs Wadam and Sestra in the background to produce unit-motion response (FD) for
# * diffraction (all selected headings) ​(DiR#.SIN)
# * radiation and inertia (6 rigid-body dofs) for user-selected frequencies (RaXX#.SIN)
# * hydrostatic pressure and gravity response ​(DiR#.SIN)
# * mooring loads and tower forces (UnitNodalR#.SIN) for nodes specified in sima.force
# <br/>
# <br/>

# %%
import subprocess,os, shutil
from pathlib import Path
import os
import glob
from dnv.sesam.commands import *
from dnv.sesam.commands.executors import execute_command
from dnv.oneworkflow import *

####### USER INPUT #########

precom_execution_folder = r"Precompute\\Execution"    # Folder where Precompute will be run
precom_output_folder =  r"Precompute\\Output"         # Folder where output of precompute is to be stored
precom_input_folder = r"Input\\precompute"            # Folder where input for precompute is stored
precompute_command = "precompute unit-response-json"  # Command line arguments for Sesam Core to run precompute of unit response 

#### END of USER INPUT ####


## Create execution and ouptut folders
execution_folder_path = os.path.join(workspacePath, precom_execution_folder)
output_folder_path = os.path.join(workspacePath, precom_output_folder )
input_folder_path = os.path.join(workspacePath, precom_input_folder)
shutil.rmtree(execution_folder_path, ignore_errors=True)
shutil.rmtree(output_folder_path, ignore_errors=True)
os.makedirs(execution_folder_path, exist_ok=True)
os.makedirs(output_folder_path, exist_ok=True)

precompute_input_file = os.path.join(execution_folder_path, "precompute_input.json")


## Create a python dictionary then replace the precompute template file with the strings from the dictionary
## All paths are relative to the workspace folder
precompute_parameters= {'inputpath': precom_input_folder,                   
                        'outputpath': precom_output_folder,
                        'executepath': precom_execution_folder,
                        'simaforce': precom_input_folder + r"\\sima.force",
                        'femfile' : precom_input_folder + r"\\" + model_prefix + "T" + str(topsuper) + ".FEM"}

precompute_input_command = CreateInputFileFromFileTemplateCommand(               # Create a command to generate the precompute_input.json by taking the precompute_input_template.json and replacing the strings with parameters for the DLC
        template_input_file  = "precompute_input_template.json",
        input_filename  = precompute_input_file,
        parameters= precompute_parameters,
        working_dir = input_folder_path
    )
execute_command(precompute_input_command)                                        # Execute the command     

## Run precompute unit response in Sesam Core
print("Running Sesam Core in folder " + execution_folder_path)
score_command = SesamCoreCommand(working_dir=workspacePath)                      # create a new Sesam Core command
score_command.arguments = precompute_command + ' -i ' + precompute_input_file    # add command line arguments to the command (run precompute)
execute_command(score_command)                                                   # execute the command to run precompute
# Out:
# INFO: The .NET Runtime Path 'C:\Users\kblu\AppData\Roaming\Python\Python312\site-packages\dnv\net\runtime\.net'
# INFO: The .NET Runtime Version '.NET 8.0.4'. Runtime Identifier 'win-x64'.
#
# Running Sesam Core in folder c:\source\sesam-time-domain-examples-internal\response-reconstruction\EMULF_Buckling_Tutorial_RR\Input\Workspace\Precompute\\Execution

# %% [markdown]
# ## Check if precomputation was successful
# This is a rudimentary check which succeeds if it finds the expected output files

# %%
print('Checking if Sesam Core precompute command has been executed successfully')
error = False

# There should be 8 .sin files + SCORE.MLG in the output folder
if (len(glob.glob(os.path.join(output_folder_path, "*.sin"))) != 8):
    print("Precompute command failed - not all SIN files have been created")
    error = True
if (not os.path.exists(os.path.join(output_folder_path, "SCORE.MLG"))):
    print("Precompute command failed - cannot find SCORE.MLG file in the output folder")
    error = True

if not error:
    print("Precompute command executed successfully")
# Out:
# Checking if Sesam Core precompute command has been executed successfully
# Precompute command executed successfully

# %% [markdown]
# ## Read DLCs from a spreadsheet

# %% [markdown]
# In the code below the name of the spreadsheet is declared as well as the capacity model file.
# In the parameter mapping an association of parameters is done which will be used for assigning each entry in the spreadsheet a corresponding variable.

# %%
import pandas as pd

####### USER INPUT #########

dlc_sheet = "DLC_input.xlsx"         # The name of the spreadsheet with the parameters of each DLC
capacity = "EMULF_ULS_All.json"      # Name of the capacity model

#### END of USER INPUT ####

## In the definition below the parameter mapping is defined which associates each column in the excel sheet with a corresponding variable in the code. 
## If you use an excel sheet with a different structure, this is where the workflow can be adjusted to interpret that sheet:
parameter_mapping = {'Group': "group",
				'LoadCase': "loadcase",
				"SimaFilesFolder": "sima_files_folder",
                "TimeStep": "timestep",
				"Depth": "depth",
				"StartBuckling": "BUCKLINGSTART",
				"StopBuckling": "BUCKLINGEND",
				                }

input_data = pd.read_excel(os.path.join(workspacePath, dlc_sheet), index_col=1) # in here the excel sheet is read
input_data

fixed_parameters_all_load_cases = {
    'mor_sel': topsuper,                                  # superelement number for the morison model, in this case the same as the structural model
    'prefix': model_prefix,                               # prefix for the morison (and structural) model
    'cap_mod': capacity,                                  # name of the capacity model, for the input.json
    'modelf' : model_prefix+"T"+str(topsuper) + ".FEM",   # name of the model file, for the input.json
    'loadf' :  model_prefix+"L"+str(topsuper) + ".FEM"    # name of the load file, for the input.json 
    }

# %% [markdown]
# ## Create tasks for each DLC
#
# In the code below the tasks are created for each analysis and for each DLC. The user may select to skip part of the workflow in the USER INPUT section, in that case make sure all necessary files for the following analysis are available. Moreover, to avoid deleting these files at the beginning of the run then declare `clean = False`.
#
# - The template files are populated with the proper values for each DLC using the [`CreateInputFileFromFileTemplateCommand`](https://myworkspace.dnv.com/download/public/sesam/workflow/docs/latest/source/dnv.oneworkflow.html#dnv.oneworkflow.create_input_file_from_file_template_command.CreateInputFileFromFileTemplateCommand) (the same method was used previously to generate the input fiel for the precompute step)

# %%
import os
import shutil
from dnv.sesam.commands import *
from dnv.oneworkflow import *

####### USER INPUT #########

# Set True for the workflow steps to be run, and False for the steps to be skipped:

run_sestra_template_command = True        # Define whether to update sestra input files with the latest variables
run_sesam_core_template_command = True    # Define whether to update sesam core input files with the latest variables
run_sesam_core = True                     # Define whether to run sestra and sesam core
run_sesam_core_input_command = True

clean = True                              # Define whether to clean (True) or keep (False) files (input and ouptut) from a previous run, if skipping any anlysis step this should be set to false.


#### END of USER INPUT ####

lc_path = os.path.join(workspacePath,"LoadCases")

## Create loadcases folders
if clean:
    shutil.rmtree(lc_path, ignore_errors=True)

workflow_sequence = []
display(input_data)

## Loop over all DLCs is run to get the parameters for each DLC, creating the DLC folders and setup the tasks.
for casename, case in input_data.iterrows():        
    tasks = []
    casedict = case.to_dict()
    input_parameters = {}
    
    for key, value in case.items():
        input_parameters[parameter_mapping[key]] = str(value)

    get_folder=os.path.join(workspacePath, input_parameters["sima_files_folder"])     # Define the path to the folder where the Sima files for this DLC are stored
    DLC_folder=os.path.join(lc_path, case.name)                                        # Define the path of the DLC folder, where the analysis will be run
   
    if not os.path.exists(DLC_folder):          
        os.makedirs(DLC_folder)                                                       # Create the DLC folder, if it does not exist already
    
    shutil.copytree(get_folder, DLC_folder, dirs_exist_ok=True)                       # Copy files from the Sima files folder to the DLC folder

    input_parameters = input_parameters | fixed_parameters_all_load_cases
    print("The following parameters are used for load case: " + casename)
    print(json.dumps(input_parameters, indent=4, sort_keys=True))
 
    sesam_core_template_command = CreateInputFileFromFileTemplateCommand(             # Create the SesamCore_buckling.jnl by taking the SesamCore_buckling_template.jnl and replacing the strings with parameters for the DLC
        template_input_file  = "SesamCore_buckling_template.jnl",
        input_filename  = "SesamCore_buckling.jnl",
        parameters= input_parameters
    )
    if run_sesam_core_template_command:
        tasks.append(sesam_core_template_command)
    
    sesam_core_input_command = CreateInputFileFromFileTemplateCommand(                # Create the SesamCore_buckling.jnl by taking the SesamCore_buckling_template.jnl and replacing the strings with parameters for the DLC
        template_input_file  = "input_template.json",
        input_filename  = "input.json",
        parameters= input_parameters
    )

    if run_sesam_core_input_command:                                                  # Create the input.json by taking the inpu_template.json and replacing the strings with parameters for the DLC
        tasks.append(sesam_core_input_command)

    if run_sesam_core:
        score_command = SesamCoreCommand(working_dir=workspacePath)    
        score_command.arguments = "uls -i input.json -rec -pt 8"
        tasks.append(score_command)
        
    workflow_sequence.append(CommandInfo(commands=tasks,load_case_foldername=casename)) # Add the generated tasks to the workflow sequence.
# Out:
#                Group     SimaFilesFolder  TimeStep  Depth  StartBuckling  \
# LoadCase
# DLC001    DLC_test_1  Input\sima_files_1       0.1    0.0            3.2
# DLC002    DLC_test_2  Input\sima_files_2       0.1    NaN           13.2
# DLC003    DLC_test_3  Input\sima_files_1       0.1    NaN           13.2
#
#           StopBuckling
# LoadCase
# DLC001             3.8
# DLC002            13.8
# DLC003            13.8
# The following parameters are used for load case: DLC001
# {
#     "BUCKLINGEND": "3.8",
#     "BUCKLINGSTART": "3.2",
#     "cap_mod": "EMULF_ULS_All.json",
#     "depth": "0.0",
#     "group": "DLC_test_1",
#     "loadf": "L3.FEM",
#     "modelf": "T3.FEM",
#     "mor_sel": 3,
#     "prefix": "",
#     "sima_files_folder": "Input\\sima_files_1",
#     "timestep": "0.1"
# }
# The following parameters are used for load case: DLC002
# {
#     "BUCKLINGEND": "13.8",
#     "BUCKLINGSTART": "13.2",
#     "cap_mod": "EMULF_ULS_All.json",
#     "depth": "nan",
#     "group": "DLC_test_2",
#     "loadf": "L3.FEM",
#     "modelf": "T3.FEM",
#     "mor_sel": 3,
#     "prefix": "",
#     "sima_files_folder": "Input\\sima_files_2",
#     "timestep": "0.1"
# }
# The following parameters are used for load case: DLC003
# {
#     "BUCKLINGEND": "13.8",
#     "BUCKLINGSTART": "13.2",
#     "cap_mod": "EMULF_ULS_All.json",
#     "depth": "nan",
#     "group": "DLC_test_3",
#     "loadf": "L3.FEM",
#     "modelf": "T3.FEM",
#     "mor_sel": 3,
#     "prefix": "",
#     "sima_files_folder": "Input\\sima_files_1",
#     "timestep": "0.1"
# }

# %% [markdown]
# ## Run the analysis
#
# In the code below we run the analysis using [`run_managed_commands_in_parallel_async`](https://myworkspace.dnv.com/download/public/sesam/workflow/docs/latest/source/dnv.oneworkflow.utils.html#dnv.oneworkflow.utils.workflow_commands_runners_parallel.run_managed_commands_in_parallel_async) with the previously created workflow client and the commands setup in the previous cell. This implies that analysis of each DLC will happen in parallel, as opposed to in sequence. We set `log_job=false` to get a more restricted log, but it can be set to `True` for more detailed logs if wanted. We set `enable_common_files_copy_to_load_cases=True` to copy files from the "CommonFiles" folder into every single DLC folder.
#
# Subsequently, the `analysisStatusChecker` is used to check whether the analysis was successful by checking Sesam Core output files.

# %%
## Run the analysis
workflow_client = one_workflow_client(workspace_id = workspaceId, cloud_run = cloudRun, workspace_path = workspacePath, inplace_execution = True)
print("Running commands in parallel")
await run_managed_commands_in_parallel_async(
             client=workflow_client,
             commands_info=workflow_sequence,
             log_job=False,
             enable_common_files_copy_to_load_cases=True,
 )

## Check if analysis is successful 

local_result_path = Path(workspacePath, workflow_client.results_directory)
prev_dir = os.getcwd()

try:
    os.chdir(local_result_path)
    import analysisStatusChecker
    analysisStatusChecker.checkSesamCoreStatus()
except:
    print('Error during analysis status check, Sesam Core may not have run successfully. Check the log files.')
    print('Please see SCORE.MLG for more information.')
finally:
    os.chdir(prev_dir)
# Out:
# Running commands in parallel
# Info: Attempt 1/10.LocalWorkflowRuntime service (PID '44852') is not ready yet. Retrying in 5 seconds.
# Info: The LocalWorkflowRuntime service (PID '44852') is ready.
# Info: The work item 3cc1b819-1026-415f-9c26-69c430d956f2 message is 'Created'
# Info: The work item DLC001 message is 'Created'
# Info: The work item DLC002 message is 'Created'
# Info: The work item DLC003 message is 'Created'
# Info: The progress of the job is '0%'. The message is ''
# Info: The work item DLC001 message is ''
# Info: The work item DLC002 message is ''
# Info: The work item DLC003 message is ''
# Info: The work item DLC001 message is 'Executing SesamCore (score.exe).'
# Info: The work item DLC002 message is 'Executing SesamCore (score.exe).'
# Info: The work item DLC003 message is 'Executing SesamCore (score.exe).'
# Info: The progress of the job is '75%'. The message is 'Completed 0 of 3 tasks of task group 3cc1b819-1026-415f-9c26-69c430d956f2'
# Info: The work item DLC001 message is '27688 elements reconstructed in 00:01:08.5199699.'
# Info: The status of work item 'DLC002' is 'Completed'
# Info: The work item DLC003 message is '27688 elements reconstructed in 00:01:08.2271454.'
# Info: The status of work item '3cc1b819-1026-415f-9c26-69c430d956f2' is 'Completed'
# Info: The status of work item 'DLC001' is 'Completed'
# Info: The status of work item 'DLC003' is 'Completed'
# Info: Job ID: dcfda521-69b6-46a0-82c9-4997fb0b495a. Job Status: Completed. Job Progress: 100%. Job Message: Job dcfda521-69b6-46a0-82c9-4997fb0b495a completed with status Completed.
# Verifying Sesam Core results:
# Assuming results to be in folder  c:\source\sesam-time-domain-examples-internal\response-reconstruction\EMULF_Buckling_Tutorial_RR\Input\Workspace\LoadCases
# Analysis was successful for all loadcases for program Sesam Core.

# %% [markdown]
# ## Buckling results aggregation over all DLCs
# Print maximum usage factor and criterion for worst stiffener on each plate group, over all load cases.
#
# Please note that unrealistic code check results might happen as this tutorial is work in progress.

# %%
import os
from pathlib import Path
import glob
import pandas as pd

from datetime import datetime

now = datetime.now()
current_time = now.strftime("%H:%M:%S")
current_date = now.strftime("%d/%m/%Y")

print("Current Time =", current_time)
print("Current Date =", current_date)

wd = os.getcwd()

try:
    panels_and_cases = pd.DataFrame()
    panel_names = set()
    for loadcase_folder_name, _ in input_data.iterrows():
        result_folder = os.path.join(workspacePath, workflow_client.results_directory, loadcase_folder_name)

        os.chdir(result_folder)

        # loop over all panel result files (csv)
        # Set threshold value for removing the first few result cases to omit extreme initial condition results

        for file in glob.glob('SesamCore_buckling_*Panel*.csv'):
            gen = pd.read_csv(file, dtype={"math score":int}, chunksize=10000000)
            panel = pd.concat((x.query("`Result case id` >= 3") for x in gen), ignore_index=True)
            panel['Plate field'] = Path(file).stem
            panel['LoadCase'] = loadcase_folder_name
            if not panel.empty:
                panels_and_cases = pd.concat([panels_and_cases,panel])
                panel_names.add(Path(file).stem)

except:
    print("Error accumulating results, please inspect analysis resultes manually.") 
finally:
    os.chdir(wd)

## Aggregating all results in a single table
results_table = pd.DataFrame(columns=['Stiffener name', 'Plate field', 'UfMax', 'UfMax criterion', 'LoadCase', 'Time'])
for panel_name in panel_names:
    panel_results = panels_and_cases.query('`Plate field` == @panel_name')
    panel_results.reset_index(inplace=True)
    if not panel_results.empty:
        results_table.loc[len(results_table.index)] = dict(panel_results.iloc[panel_results['UfMax'].idxmax()])
        
## Sorting by UfMax
results_table.sort_values(by='UfMax', ascending=False, inplace=True)

print(f"Maximum Uf for each panel, taken over all load cases and result cases.")
print(f"Note that the first two time steps (usually extreme results) have been filtered out to avoid reporting unrealistic peak results.")

# Adjust the display settings to show all rows
pd.options.display.max_rows = 800

## Pandas provides many different ways to visualize the data. Here we just dump the results to the output
display(results_table)

## Pandas DataFrames can be exported to a number of different output formats, such as Excel, CSV, json, XML, HTML, Parquet, etc.
## Uncomment the lines below to experiment with different output formats
# results_table.to_excel(os.path.join(workspacePath, 'results.xlsx'), index=False)
# results_table.to_html(os.path.join(workspacePath, 'results.html'), index=False)
# Out:
# Current Time = 13:09:41
# Current Date = 12/07/2024
# Maximum Uf for each panel, taken over all load cases and result cases.
# Note that the first two time steps (usually extreme results) have been filtered out to avoid reporting unrealistic peak results.
#                                         Stiffener name  \
# 251                               Stiffener_Pl3006_11_
# 593                                 Stiffener_Pl437_3_
# 494                                Stiffener_Pl503_16_
# 643                                 Stiffener_Pl822_3_
# 539                                  Stiffener_Pl27_1_
# 341                                Stiffener_Pl101_17_
# 528                                 Stiffener_Pl454_4_
# 588                                 Stiffener_Pl462_3_
# 451                                Stiffener_Pl280_26_
# 320                                 Stiffener_Pl283_7_
# 376                           Stiffener_Pl505_Pl688_2_
# 682                                Stiffener_Pl283_30_
# 580                                 Stiffener_Pl272_2_
# 675                             Stiffener_Pl538_Pl993_
# 455                                Stiffener_Pl277_14_
# 366                     Stiffener_Pl21_Pl995_Pl378873_
# 474                                 Stiffener_Pl832_8_
# 328                                 Stiffener_Pl825_5_
# 313                                 Stiffener_Pl386_5_
# 38                                   Stiffener_Pl92_2_
# 180                                Stiffener_Pl759_18_
# 30                                  Stiffener_Pl477_7_
# 653                                 Stiffener_Pl19_31_
# 638                                Stiffener_Pl283_22_
# 484                                Stiffener_Pl759_15_
# 413                                Stiffener_Pl100_26_
# 211                                  Stiffener_Pl19_7_
# 527                                 Stiffener_Pl823_1_
# 145                           Stiffener_Pl482_Pl563_2_
# 167                                 Stiffener_Pl277_8_
# 296                                  Stiffener_Pl97_2_
# 239                                Stiffener_Pl768_12_
# 240                                 Stiffener_Pl900_8_
# 347                                Stiffener_Pl904_11_
# 694                                 Stiffener_Pl823_6_
# 529                                Stiffener_Pl764_42_
# 207                                Stiffener_Pl486_31_
# 292                                Stiffener_Pl462_23_
# 39                                  Stiffener_Pl916_1_
# 110                                 Stiffener_Pl283_9_
# 388                                Stiffener_Pl764_52_
# 187                                   Stiffener_Pl2_2_
# 75                                 Stiffener_Pl480_27_
# 238                              Stiffener_Pl53450_40_
# 517                                Stiffener_Pl277_11_
# 192                           Stiffener_Pl472_Pl564_3_
# 710                                Stiffener_Pl759_30_
# 343                                Stiffener_Pl759_11_
# 696                                Stiffener_Side_o_4_
# 169                               Stiffener_Pl6342_49_
# 652                                 Stiffener_Pl19_15_
# 535                                Stiffener_Pl277_27_
# 418                                Stiffener_Pl905_19_
# 628                                  Stiffener_Pl19_3_
# 541                                Stiffener_Pl283_35_
# 277                                 Stiffener_Pl462_6_
# 661                                 Stiffener_Pl764_7_
# 216                                 Stiffener_Pl19_42_
# 533                                  Stiffener_Pl2_31_
# 170           Stiffener_Pl415_Pl873_Pl879_Pl985_Pl991_
# 129                           Stiffener_Pl540_Pl970_2_
# 334                                 Stiffener_Pl233_4_
# 542                                Stiffener_Pl480_18_
# 457                                Stiffener_Pl480_24_
# 714                           Stiffener_Pl504_Pl689_3_
# 3                                  Stiffener_Pl480_31_
# 371                                Stiffener_Pl277_46_
# 243                                Stiffener_Pl759_35_
# 668  Stiffener_Pl231_Pl443_Pl489_Pl492_Pl515_Pl522_...
# 464                                 Stiffener_Pl535_3_
# 545                                 Stiffener_Pl487_2_
# 574                                 Stiffener_Pl439_4_
# 221                                Stiffener_Pl900_13_
# 47                                  Stiffener_Pl537_3_
# 105                                 Stiffener_Pl814_2_
# 523                           Stiffener_Pl518_Pl627_2_
# 600                            Stiffener_Pl19_Pl283_1_
# 56                                 Stiffener_Pl3006_9_
# 559                                Stiffener_Pl502_18_
# 269                                Stiffener_Pl277_20_
# 250                                Stiffener_Pl277_42_
# 584                                  Stiffener_Pl93_2_
# 677                                  Stiffener_Pl39_3_
# 205                                 Stiffener_Pl19_37_
# 514                                 Stiffener_Pl455_4_
# 171                                 Stiffener_Pl503_8_
# 531                                 Stiffener_Pl896_3_
# 658                                  Stiffener_Pl40_3_
# 224                                Stiffener_Pl389_10_
# 276                                Stiffener_Pl502_22_
# 353                                 Stiffener_Pl913_1_
# 291                                Stiffener_Pl503_18_
# 321                                Stiffener_Pl487_22_
# 569                                Stiffener_Pl283_41_
# 365                                 Stiffener_Pl19_33_
# 106                                Stiffener_Pl3006_1_
# 245                               Stiffener_Pl1167_24_
# 684                                Stiffener_Pl462_40_
# 190                               Stiffener_Pl1167_17_
# 476                                  Stiffener_Pl2_11_
# 202                               Stiffener_Pl3008_28_
# 645                                 Stiffener_Pl904_1_
# 708                                Stiffener_Pl283_19_
# 152                                Stiffener_Pl767_44_
# 613                                 Stiffener_Pl897_2_
# 8                                    Stiffener_Pl28_3_
# 93                                 Stiffener_Pl900_15_
# 612                                 Stiffener_Pl815_2_
# 323                         Stiffener_Pl767_Pl53450_2_
# 263                                Stiffener_Pl759_41_
# 369                                Stiffener_Pl900_14_
# 519                               Stiffener_Pl3006_33_
# 166                                  Stiffener_Pl2_26_
# 348                                 Stiffener_Pl382_3_
# 287                                Stiffener_Pl480_40_
# 297                               Stiffener_Pl6357_22_
# 586                                 Stiffener_Pl940_6_
# 424                                 Stiffener_Pl389_4_
# 403                                Stiffener_Pl277_24_
# 85                                 Stiffener_Pl502_28_
# 68                                  Stiffener_Pl825_2_
# 402                                Stiffener_Pl462_10_
# 219                                 Stiffener_Pl386_2_
# 506                                Stiffener_Pl983_11_
# 11                                  Stiffener_Pl868_6_
# 524                                Stiffener_Pl462_14_
# 364                               Stiffener_Pl1167_22_
# 230                          Stiffener_Pl759_Pl6347_1_
# 188                               Stiffener_Pl53426_5_
# 262                               Stiffener_Pl3008_20_
# 99                                  Stiffener_Pl380_6_
# 385                                 Stiffener_Pl19_10_
# 690                                 Stiffener_Pl539_1_
# 13                                 Stiffener_Pl462_31_
# 463                                 Stiffener_Pl19_18_
# 84                                 Stiffener_Pl283_38_
# 254                                Stiffener_Pl486_27_
# 185                              Stiffener_Pl52523_58_
# 324                                Stiffener_Pl480_44_
# 77                                 Stiffener_Pl480_35_
# 157                                Stiffener_Pl277_31_
# 98                                Stiffener_Pl3006_25_
# 255                                 Stiffener_Pl800_1_
# 0                                  Stiffener_Pl868_42_
# 332                                  Stiffener_Pl91_4_
# 657                                Stiffener_Pl868_36_
# 597                                  Stiffener_Pl2_43_
# 165                               Stiffener_Pl6342_26_
# 449                                Stiffener_Pl101_11_
# 249                                 Stiffener_Pl19_27_
# 22                                  Stiffener_Pl914_2_
# 372                               Stiffener_Pl1167_19_
# 139                                Stiffener_Pl277_36_
# 470                                   Stiffener_Pl2_6_
# 511                                 Stiffener_Pl480_8_
# 631                                  Stiffener_Pl2_15_
# 603                                  Stiffener_Pl52_1_
# 623                                Stiffener_Pl462_43_
# 100                                  Stiffener_Pl2_18_
# 136                                 Stiffener_Pl863_1_
# 146                           Stiffener_Pl516_Pl628_3_
# 162                                Stiffener_Pl759_27_
# 67                                 Stiffener_Pl868_30_
# 273                               Stiffener_Pl6342_12_
# 242                                Stiffener_Pl101_23_
# 69                                Stiffener_Pl1167_16_
# 392                                Stiffener_Pl277_39_
# 396                                Stiffener_Pl462_26_
# 543                               Stiffener_Pl6342_32_
# 178                                 Stiffener_Pl766_3_
# 355                                 Stiffener_Pl922_1_
# 336                             Stiffener_Pl2_Pl277_4_
# 587                                 Stiffener_Pl381_3_
# 231                                Stiffener_Pl3006_5_
# 398                               Stiffener_Pl3006_13_
# 676                                  Stiffener_Pl58_1_
# 16                                 Stiffener_Pl3006_7_
# 331                               Stiffener_Pl6347_17_
# 201                                Stiffener_Pl480_15_
# 72                            Stiffener_Pl485_Pl560_2_
# 155                                 Stiffener_Pl498_2_
# 325                                  Stiffener_Pl92_1_
# 92                                   Stiffener_Pl93_7_
# 532                                 Stiffener_Pl232_2_
# 701                                Stiffener_Pl868_24_
# 649                                  Stiffener_Pl2_40_
# 127                                 Stiffener_Pl904_8_
# 109                                Stiffener_Pl503_26_
# 401                                Stiffener_Pl905_28_
# 32                                  Stiffener_Pl19_22_
# 46                                  Stiffener_Pl801_2_
# 667                                 Stiffener_Pl767_4_
# 479                                  Stiffener_Pl48_1_
# 210                                 Stiffener_Pl983_2_
# 505                                  Stiffener_Pl8_16_
# 460                               Stiffener_Pl6347_43_
# 65                                   Stiffener_Pl2_35_
# 264                                Stiffener_Pl868_10_
# 648                               Stiffener_Pl6347_14_
# 29                                 Stiffener_Pl767_20_
# 179                                 Stiffener_Pl503_6_
# 573                             Stiffener_Pl799_Pl866_
# 71                                Stiffener_Pl3006_27_
# 154                                  Stiffener_Pl8_20_
# 556                                   Stiffener_Pl691_
# 322                                Stiffener_Pl480_46_
# 619                              Stiffener_Pl52523_30_
# 302                                  Stiffener_Pl11_1_
# 716                                Stiffener_Pl913_10_
# 439                          Stiffener_Pl868_Pl6357_4_
# 642                                  Stiffener_Pl13_4_
# 465                               Stiffener_Pl1004_11_
# 62                                 Stiffener_Pl768_17_
# 133                                Stiffener_Pl6347_7_
# 335                                 Stiffener_Pl902_2_
# 244                                Stiffener_Pl905_20_
# 274                                Stiffener_Pl759_38_
# 698                                 Stiffener_Pl831_3_
# 639                              Stiffener_Pl53450_18_
# 707                                Stiffener_Pl868_20_
# 253                               Stiffener_Pl6347_27_
# 530                                Stiffener_Pl759_23_
# 712                                Stiffener_Pl897_25_
# 691                               Stiffener_Pl6357_44_
# 394                              Stiffener_Pl53450_34_
# 632                                Stiffener_Pl503_20_
# 395                              Stiffener_Pl53450_44_
# 6                                  Stiffener_Pl767_26_
# 480                              Stiffener_Pl53450_47_
# 695                                Stiffener_Pl767_40_
# 544                                  Stiffener_Pl59_6_
# 267                                Stiffener_Pl232_11_
# 63                                  Stiffener_Pl102_3_
# 208                                Stiffener_Pl389_22_
# 570                                Stiffener_Pl767_23_
# 137                                 Stiffener_Pl536_5_
# 233                               Stiffener_Pl53450_6_
# 578                                Stiffener_Pl767_12_
# 223                              Stiffener_Pl53450_15_
# 28                                   Stiffener_Pl10_4_
# 158                                 Stiffener_Pl901_2_
# 577                               Stiffener_Pl6357_11_
# 299                                 Stiffener_Pl525_1_
# 119                                 Stiffener_Pl768_5_
# 144                               Stiffener_Pl1167_26_
# 400                                  Stiffener_Pl8_18_
# 213                              Stiffener_Pl53450_26_
# 104                                Stiffener_Pl503_12_
# 646                                 Stiffener_Pl438_1_
# 421                                 Stiffener_Pl232_5_
# 375                                Stiffener_Pl503_22_
# 134                               Stiffener_Pl6357_34_
# 266                             Stiffener_Pl895_Pl899_
# 271                                Stiffener_Pl274_55_
# 81                                   Stiffener_Pl61_6_
# 112                                 Stiffener_Pl902_3_
# 616                               Stiffener_Pl6347_29_
# 459                                 Stiffener_Pl413_2_
# 15                                  Stiffener_Pl764_2_
# 247                                   Stiffener_Pl8_8_
# 482                           Stiffener_Pl462_Pl480_2_
# 503                                 Stiffener_Pl100_2_
# 282                                Stiffener_Pl6357_6_
# 508                                Stiffener_Pl764_17_
# 693                               Stiffener_Pl6342_44_
# 504                                 Stiffener_Pl824_1_
# 453                                Stiffener_Pl275_28_
# 704                           Stiffener_Pl436_Pl626_1_
# 666                               Stiffener_Pl6357_26_
# 423                                 Stiffener_Pl822_4_
# 12                                  Stiffener_Pl931_1_
# 149                                Stiffener_Pl487_10_
# 66                               Stiffener_Pl52523_50_
# 314                               Stiffener_Pl6357_20_
# 490                                 Stiffener_Pl497_2_
# 438                                Stiffener_Pl764_37_
# 367                                Stiffener_Pl100_22_
# 566                                  Stiffener_Pl57_3_
# 315                                Stiffener_Pl1004_4_
# 585                                 Stiffener_Pl767_8_
# 303                               Stiffener_Pl6357_32_
# 227                           Stiffener_Pl484_Pl561_3_
# 173                                  Stiffener_Pl8_30_
# 5                                   Stiffener_Pl503_4_
# 590                                 Stiffener_Pl759_5_
# 644                                 Stiffener_Pl925_2_
# 290                                 Stiffener_Pl447_2_
# 380                               Stiffener_Pl1004_12_
# 572                                Stiffener_Pl487_12_
# 500                               Stiffener_Pl6347_23_
# 261                              Stiffener_Pl53450_11_
# 488                               Stiffener_Pl3006_19_
# 218                                 Stiffener_Pl456_3_
# 445                                Stiffener_Pl486_17_
# 86                                 Stiffener_Pl487_34_
# 685                                  Stiffener_Pl57_2_
# 537                               Stiffener_Pl6347_37_
# 94                                  Stiffener_Pl818_2_
# 641                                 Stiffener_Pl832_5_
# 123                              Stiffener_Pl53450_32_
# 326                                 Stiffener_Pl441_2_
# 265                                Stiffener_Pl767_32_
# 655                                Stiffener_Pl488_27_
# 9                                   Stiffener_Pl486_3_
# 607                                Stiffener_Pl768_48_
# 209                                  Stiffener_Pl93_6_
# 415                                Stiffener_Pl487_26_
# 229                                 Stiffener_Pl897_9_
# 344                            Stiffener_Pl95_Pl565_2_
# 387                                Stiffener_Pl868_16_
# 442                               Stiffener_Pl1024_11_
# 203                                Stiffener_Pl462_20_
# 234                                 Stiffener_Pl517_4_
# 687                         Stiffener_Pl3237_Pl7352_3_
# 589                                 Stiffener_Pl761_4_
# 601                                   Stiffener_Pl692_
# 33                                  Stiffener_Pl759_1_
# 42                                 Stiffener_Pl488_31_
# 664                                Stiffener_Pl868_38_
# 507                                 Stiffener_Pl945_5_
# 176                                  Stiffener_Pl2_24_
# 670                                 Stiffener_Pl833_4_
# 345                                Stiffener_Pl101_25_
# 391                                Stiffener_Pl285_27_
# 635                                 Stiffener_Pl478_2_
# 430                                 Stiffener_Pl926_2_
# 633                                 Stiffener_Pl438_9_
# 356                                  Stiffener_Pl8_22_
# 454                               Stiffener_Pl3008_17_
# 204                                Stiffener_Pl501_30_
# 118                                Stiffener_Pl274_14_
# 502                               Stiffener_Pl6347_33_
# 35                                  Stiffener_Pl517_5_
# 606                                  Stiffener_Pl8_10_
# 540                                Stiffener_Pl898_10_
# 43                                 Stiffener_Pl488_15_
# 183                                 Stiffener_Pl479_2_
# 568                                Stiffener_Pl768_37_
# 107                                Stiffener_Pl502_10_
# 235                                Stiffener_Pl100_16_
# 206                                Stiffener_Pl766_19_
# 222                                Stiffener_Pl503_24_
# 467                               Stiffener_Pl41230_1_
# 252                               Stiffener_Pl6342_31_
# 461                               Stiffener_Pl6357_47_
# 197                                  Stiffener_Pl91_7_
# 330                                 Stiffener_Pl536_4_
# 615                              Stiffener_Pl53426_10_
# 54                                 Stiffener_Pl766_39_
# 362                                 Stiffener_Pl905_2_
# 477                               Stiffener_Pl3008_22_
# 346                                 Stiffener_Pl766_7_
# 447                                 Stiffener_Pl475_1_
# 493                                Stiffener_Pl488_23_
# 561                                Stiffener_Pl1004_7_
# 126                                Stiffener_Pl487_32_
# 172                               Stiffener_Pl6347_10_
# 79                                 Stiffener_Pl503_30_
# 2                                 Stiffener_Pl1167_29_
# 440                                Stiffener_Pl389_27_
# 288                                Stiffener_Pl487_30_
# 381                                 Stiffener_Pl285_6_
# 342                               Stiffener_Pl52523_8_
# 128                                 Stiffener_Pl915_4_
# 436                                 Stiffener_Pl382_6_
# 278                                Stiffener_Pl487_16_
# 558                                Stiffener_Pl462_34_
# 433                                Stiffener_Pl501_26_
# 122                              Stiffener_Pl53450_23_
# 471                               Stiffener_Pl22328_2_
# 225                                Stiffener_Pl502_12_
# 427                                 Stiffener_Pl941_4_
# 50                                 Stiffener_Pl488_13_
# 680                                Stiffener_Pl868_28_
# 175                               Stiffener_Pl6342_56_
# 674                                Stiffener_Pl897_20_
# 284                                 Stiffener_Pl768_3_
# 142                                 Stiffener_Pl824_6_
# 275                                Stiffener_Pl867_13_
# 194                                  Stiffener_Pl53_3_
# 258                                   Stiffener_Pl3_2_
# 18                                Stiffener_Pl6342_41_
# 199                                 Stiffener_Pl941_5_
# 214                                Stiffener_Pl100_20_
# 143                                Stiffener_Pl768_24_
# 27                                 Stiffener_Pl768_43_
# 124                               Stiffener_Pl6357_40_
# 215                                  Stiffener_Pl56_9_
# 443                                 Stiffener_Pl98_10_
# 361                                   Stiffener_Pl8_2_
# 377                                Stiffener_Pl486_13_
# 31                                 Stiffener_Pl766_24_
# 553                                Stiffener_Pl766_30_
# 637                               Stiffener_Pl3006_21_
# 525                                Stiffener_Pl501_24_
# 571                                 Stiffener_Pl812_1_
# 279                                Stiffener_Pl486_29_
# 408                                 Stiffener_Pl488_7_
# 384                                Stiffener_Pl274_21_
# 659                               Stiffener_Pl3008_21_
# 422                              Stiffener_Pl52523_38_
# 650                                  Stiffener_Pl8_24_
# 280                                  Stiffener_Pl37_4_
# 486                                 Stiffener_Pl423_4_
# 583                                 Stiffener_Pl913_3_
# 338                               Stiffener_Pl3008_29_
# 444                                  Stiffener_Pl51_1_
# 409                                Stiffener_Pl274_40_
# 256                                 Stiffener_Pl941_6_
# 702                                Stiffener_Pl764_13_
# 554                                 Stiffener_Pl993_4_
# 195                                  Stiffener_Pl12_1_
# 564                               Stiffener_Pl3008_26_
# 654                                 Stiffener_Pl983_5_
# 360                                 Stiffener_Pl442_2_
# 196                               Stiffener_Pl7352_51_
# 420                                Stiffener_Pl501_22_
# 74                                 Stiffener_Pl767_16_
# 21                                 Stiffener_Pl283_27_
# 20                                   Stiffener_Pl57_4_
# 270                                Stiffener_Pl867_43_
# 399                                 Stiffener_Pl423_5_
# 153                                 Stiffener_Pl898_8_
# 563                                Stiffener_Pl768_33_
# 148                               Stiffener_Pl3237_21_
# 431                                 Stiffener_Pl488_3_
# 151                                  Stiffener_Pl60_7_
# 378                               Stiffener_Pl1167_27_
# 241                                Stiffener_Pl274_18_
# 672                                 Stiffener_Pl893_2_
# 536                               Stiffener_Pl3008_16_
# 198                                Stiffener_Pl285_13_
# 715                               Stiffener_Pl7352_54_
# 683                               Stiffener_Pl3237_23_
# 49                               Stiffener_Pl369960_1_
# 246                               Stiffener_Pl6357_15_
# 689                                Stiffener_Pl275_45_
# 311                                 Stiffener_Pl867_3_
# 660                               Stiffener_Pl3008_23_
# 312                                Stiffener_Pl3006_3_
# 10                                   Stiffener_Pl61_2_
# 101                                Stiffener_Pl283_13_
# 272                                Stiffener_Pl100_10_
# 95                                   Stiffener_Pl56_7_
# 318                                Stiffener_Pl867_31_
# 96                                  Stiffener_Pl502_8_
# 495                                 Stiffener_Pl487_6_
# 114                               Stiffener_Pl7352_31_
# 699                                 Stiffener_Pl857_1_
# 220                                Stiffener_Pl487_14_
# 373                                 Stiffener_Pl501_6_
# 138                                 Stiffener_Pl919_3_
# 546                                Stiffener_Pl501_16_
# 55                                   Stiffener_Pl98_5_
# 359                               Stiffener_Pl3237_16_
# 501                               Stiffener_Pl3237_15_
# 515                                Stiffener_Pl867_36_
# 552                                Stiffener_Pl767_36_
# 132                                 Stiffener_Pl477_6_
# 621                               Stiffener_Pl3237_17_
# 618                               Stiffener_Pl7352_28_
# 706                                Stiffener_Pl100_18_
# 594                                Stiffener_Pl274_53_
# 293                               Stiffener_Pl3237_19_
# 404                                Stiffener_Pl100_28_
# 560                                 Stiffener_Pl904_2_
# 602                                 Stiffener_Pl944_6_
# 259                                Stiffener_Pl101_29_
# 285                                  Stiffener_Pl56_2_
# 310                                 Stiffener_Pl380_1_
# 58                          Stiffener_Pl768_Pl52523_1_
# 522                           Stiffener_Pl275_Pl766_2_
# 435                           Stiffener_Pl483_Pl562_2_
# 57                                 Stiffener_Pl913_12_
# 44                                 Stiffener_Pl503_14_
# 456                                Stiffener_Pl275_50_
# 309                                 Stiffener_Pl487_4_
# 681                                Stiffener_Pl100_30_
# 509                                Stiffener_Pl867_52_
# 512                                Stiffener_Pl100_12_
# 354                                Stiffener_Pl502_16_
# 374                                 Stiffener_Pl902_8_
# 393                                 Stiffener_Pl487_8_
# 164                                 Stiffener_Pl486_1_
# 168                               Stiffener_Pl3006_23_
# 429                               Stiffener_Pl7352_35_
# 115                                 Stiffener_Pl101_5_
# 14                                Stiffener_Pl7352_33_
# 579                                Stiffener_Pl898_12_
# 305                                Stiffener_Pl274_46_
# 492                              Stiffener_Pl52523_43_
# 304                                  Stiffener_Pl98_6_
# 555                                Stiffener_Pl274_51_
# 547                               Stiffener_Pl6342_57_
# 437                                 Stiffener_Pl488_5_
# 605                                 Stiffener_Pl940_5_
# 390                              Stiffener_Pl52523_12_
# 340                                Stiffener_Pl867_19_
# 665                                 Stiffener_Pl525_3_
# 113                                Stiffener_Pl766_50_
# 452                                Stiffener_Pl487_20_
# 87                                 Stiffener_Pl768_25_
# 711                                 Stiffener_Pl802_2_
# 268                                 Stiffener_Pl486_5_
# 549                                 Stiffener_Pl438_8_
# 406                               Stiffener_Pl3237_34_
# 358                                 Stiffener_Pl867_7_
# 189                                Stiffener_Pl766_25_
# 130                               Stiffener_Pl1167_20_
# 51                                  Stiffener_Pl831_6_
# 598                                 Stiffener_Pl892_2_
# 497                                  Stiffener_Pl14_1_
# 448                               Stiffener_Pl7352_36_
# 352                                Stiffener_Pl480_12_
# 327                                Stiffener_Pl867_41_
# 521                                Stiffener_Pl944_11_
# 596                                Stiffener_Pl867_47_
# 462                                   Stiffener_Pl8_4_
# 306                               Stiffener_Pl1167_28_
# 350                                 Stiffener_Pl925_7_
# 705                                Stiffener_Pl488_19_
# 397                                Stiffener_Pl280_17_
# 582                                 Stiffener_Pl503_2_
# 177                                 Stiffener_Pl501_8_
# 651                                Stiffener_Pl101_13_
# 295                                 Stiffener_Pl535_4_
# 624                                 Stiffener_Pl903_1_
# 286                                   Stiffener_Pl8_6_
# 228                                 Stiffener_Pl944_2_
# 37                                  Stiffener_Pl813_2_
# 121                               Stiffener_Pl3008_30_
# 592                                 Stiffener_Pl943_2_
# 191                                 Stiffener_Pl925_9_
# 630                                 Stiffener_Pl101_1_
# 526                              Stiffener_Pl52523_23_
# 557                           Stiffener_Pl854_Pl868_2_
# 159                                 Stiffener_Pl537_4_
# 419                                 Stiffener_Pl422_6_
# 496                                Stiffener_Pl501_12_
# 182                                Stiffener_Pl275_42_
# 487                                  Stiffener_Pl55_1_
# 379                                 Stiffener_Pl486_7_
# 147                                Stiffener_Pl503_28_
# 692                                 Stiffener_Pl422_2_
# 116                                Stiffener_Pl764_23_
# 120                                 Stiffener_Pl902_1_
# 679                               Stiffener_Pl3008_27_
# 636                                  Stiffener_Pl8_12_
# 483                                 Stiffener_Pl440_2_
# 316                                Stiffener_Pl285_18_
# 700                                Stiffener_Pl275_10_
# 88                                  Stiffener_Pl943_9_
# 226                                Stiffener_Pl764_49_
# 405                                Stiffener_Pl867_24_
# 24                                Stiffener_Pl3006_29_
# 709                                Stiffener_Pl281_46_
# 298                                Stiffener_Pl768_54_
# 301                                Stiffener_Pl766_43_
# 576                                  Stiffener_Pl22_2_
# 595                                  Stiffener_Pl59_5_
# 289                                 Stiffener_Pl942_1_
# 363                                 Stiffener_Pl917_3_
# 181                                Stiffener_Pl281_49_
# 102                                 Stiffener_Pl486_9_
# 686                                 Stiffener_Pl944_1_
# 489                                Stiffener_Pl274_44_
# 26                                Stiffener_Pl3008_25_
# 78                                 Stiffener_Pl275_19_
# 317                                 Stiffener_Pl488_1_
# 131                                Stiffener_Pl766_13_
# 76                                 Stiffener_Pl945_12_
# 604                                  Stiffener_Pl8_14_
# 610                               Stiffener_Pl53426_6_
# 236                                Stiffener_Pl487_18_
# 36                                   Stiffener_Pl54_3_
# 473                                 Stiffener_Pl897_8_
# 472                                 Stiffener_Pl285_7_
# 61                                 Stiffener_Pl766_47_
# 150                                 Stiffener_Pl945_7_
# 200                                 Stiffener_Pl383_1_
# 468                                Stiffener_Pl281_48_
# 156                                Stiffener_Pl275_57_
# 446                                Stiffener_Pl897_16_
# 357                                Stiffener_Pl503_10_
# 370                                Stiffener_Pl281_53_
# 386                                 Stiffener_Pl501_4_
# 426                                Stiffener_Pl501_28_
# 673                                  Stiffener_Pl8_28_
# 40                                  Stiffener_Pl285_4_
# 103                                  Stiffener_Pl50_2_
# 466                                Stiffener_Pl488_29_
# 294                                 Stiffener_Pl423_9_
# 656                                Stiffener_Pl764_33_
# 425                           Stiffener_Pl280_Pl867_5_
# 551                                 Stiffener_Pl502_2_
# 688                               Stiffener_Pl1167_25_
# 499                                Stiffener_Pl764_29_
# 450                              Stiffener_Pl52523_48_
# 412                                Stiffener_Pl101_15_
# 417                              Stiffener_Pl52523_18_
# 611                                Stiffener_Pl502_30_
# 481                                Stiffener_Pl101_21_
# 713                                Stiffener_Pl281_52_
# 160                                Stiffener_Pl281_50_
# 513                               Stiffener_Pl1167_18_
# 82                                 Stiffener_Pl486_21_
# 678                                 Stiffener_Pl943_7_
# 45                                 Stiffener_Pl275_20_
# 64                                 Stiffener_Pl101_27_
# 510                                 Stiffener_Pl519_2_
# 627                                 Stiffener_Pl894_1_
# 70                                 Stiffener_Pl486_25_
# 141                                Stiffener_Pl280_57_
# 135                          Stiffener_Pl764_Pl6342_5_
# 516                                 Stiffener_Pl441_7_
# 260                                Stiffener_Pl281_22_
# 232                                Stiffener_Pl487_28_
# 117                                Stiffener_Pl275_35_
# 111                                Stiffener_Pl502_14_
# 647                                Stiffener_Pl897_30_
# 283                                Stiffener_Pl502_26_
# 434                                 Stiffener_Pl502_4_
# 59                                  Stiffener_Pl501_2_
# 19                                 Stiffener_Pl501_10_
# 432                               Stiffener_Pl6342_21_
# 237                                Stiffener_Pl501_18_
# 90                                 Stiffener_Pl488_17_
# 4                                 Stiffener_Pl3237_54_
# 617                               Stiffener_Pl1167_30_
# 416                                  Stiffener_Pl59_4_
# 368                               Stiffener_Pl3006_15_
# 581                               Stiffener_Pl33244_3_
# 414                                 Stiffener_Pl488_9_
# 333                               Stiffener_Pl3006_17_
# 300                                Stiffener_Pl1024_3_
# 23                                 Stiffener_Pl280_31_
# 562                                 Stiffener_Pl519_4_
# 1                                  Stiffener_Pl275_33_
# 608                                Stiffener_Pl280_39_
# 640                                 Stiffener_Pl60_11_
# 575                                 Stiffener_Pl441_6_
# 520                               Stiffener_Pl3237_25_
# 80                                  Stiffener_Pl275_5_
# 534                                  Stiffener_Pl38_3_
# 108                               Stiffener_Pl1024_12_
# 634                               Stiffener_Pl3008_19_
# 97                                  Stiffener_Pl944_7_
# 458                                  Stiffener_Pl60_2_
# 599                                Stiffener_Pl1024_8_
# 163                                  Stiffener_Pl60_1_
# 91                                Stiffener_Pl3008_24_
# 662                                Stiffener_Pl487_24_
# 7                                   Stiffener_Pl918_1_
# 52                                 Stiffener_Pl274_35_
# 60                                Stiffener_Pl7352_41_
# 339               Stiffener_Pl506_Pl687_Pl798_Pl837_1_
# 411                              Stiffener_Pl52523_29_
# 184                               Stiffener_Pl1167_21_
# 620                                  Stiffener_Pl61_7_
# 89                                 Stiffener_Pl100_14_
# 319                               Stiffener_Pl7352_16_
# 193                                  Stiffener_Pl60_9_
# 217                                Stiffener_Pl940_10_
# 663                               Stiffener_Pl6342_11_
# 441                                Stiffener_Pl488_21_
# 186                                Stiffener_Pl280_46_
# 491                                  Stiffener_Pl49_1_
# 428                               Stiffener_Pl3237_32_
# 625                                  Stiffener_Pl8_26_
# 703                                Stiffener_Pl280_49_
# 48                                 Stiffener_Pl8554_3_
# 212                                Stiffener_Pl285_26_
# 351                                 Stiffener_Pl101_9_
# 410                               Stiffener_Pl3006_31_
# 349                                 Stiffener_Pl490_2_
# 626                               Stiffener_Pl7352_26_
# 83                                   Stiffener_Pl94_2_
# 140                               Stiffener_Pl3008_18_
# 308                                 Stiffener_Pl280_9_
# 41                                  Stiffener_Pl491_1_
# 669                                Stiffener_Pl501_20_
# 329                                 Stiffener_Pl494_1_
# 567                                Stiffener_Pl486_19_
# 34                                 Stiffener_Pl281_18_
# 382                                Stiffener_Pl486_15_
# 697                                Stiffener_Pl281_47_
# 248                                Stiffener_Pl486_11_
# 498                                Stiffener_Pl488_25_
# 485                                Stiffener_Pl280_33_
# 565                                 Stiffener_Pl100_4_
# 591                               Stiffener_Pl1167_23_
# 629                           Stiffener_Pl274_Pl281_3_
# 281                                Stiffener_Pl274_49_
# 518                                 Stiffener_Pl101_7_
# 73                                  Stiffener_Pl414_2_
# 478                                Stiffener_Pl488_11_
# 609                                Stiffener_Pl502_24_
# 17                                 Stiffener_Pl486_23_
# 407                                Stiffener_Pl502_20_
# 257                                Stiffener_Pl501_14_
# 538                               Stiffener_Pl3237_14_
# 550                                Stiffener_Pl897_32_
# 614                                Stiffener_Pl280_56_
# 389                                 Stiffener_Pl502_6_
# 671                                 Stiffener_Pl100_8_
# 383                                Stiffener_Pl100_24_
# 469                                 Stiffener_Pl101_3_
# 548                                Stiffener_Pl285_31_
# 174                                 Stiffener_Pl100_6_
# 307                                Stiffener_Pl281_43_
# 337                                Stiffener_Pl280_14_
# 53                                  Stiffener_Pl816_3_
# 161                                 Stiffener_Pl422_7_
# 125                                Stiffener_Pl101_19_
# 622                                 Stiffener_Pl891_1_
# 25                                  Stiffener_Pl496_1_
# 475                                Stiffener_Pl517_12_
#
#                                            Plate field     UfMax  \
# 251  SesamCore_buckling_panel_Pl3006_11__to__Pl3006...  8770.000
# 593     SesamCore_buckling_panel_Pl437_4__to__Pl437_1_  7170.000
# 494   SesamCore_buckling_panel_Pl503_16__to__Pl503_15_  7110.000
# 643     SesamCore_buckling_panel_Pl822_7__to__Pl822_1_  5340.000
# 539       SesamCore_buckling_panel_Pl27_1__to__Pl27_4_  3410.000
# 341   SesamCore_buckling_panel_Pl101_17__to__Pl101_18_  3110.000
# 528     SesamCore_buckling_panel_Pl454_4__to__Pl454_2_  3020.000
# 588     SesamCore_buckling_panel_Pl462_4__to__Pl462_1_  2930.000
# 451   SesamCore_buckling_panel_Pl280_26__to__Pl280_20_  2750.000
# 320     SesamCore_buckling_panel_Pl283_5__to__Pl283_8_  2510.000
# 376  SesamCore_buckling_panel_Pl505_Pl688_4__to__Pl...  2320.000
# 682   SesamCore_buckling_panel_Pl283_29__to__Pl283_32_  1880.000
# 580     SesamCore_buckling_panel_Pl272_4__to__Pl272_1_  1820.000
# 675  SesamCore_buckling_panel_Pl538_Pl993__to__Pl99...  1790.000
# 455   SesamCore_buckling_panel_Pl277_16__to__Pl277_13_  1760.000
# 366  SesamCore_buckling_panel_Pl21_3__to__Pl995_Pl3...  1680.000
# 474     SesamCore_buckling_panel_Pl832_8__to__Pl832_2_  1660.000
# 328     SesamCore_buckling_panel_Pl825_1__to__Pl825_7_  1620.000
# 313     SesamCore_buckling_panel_Pl386_1__to__Pl386_7_  1580.000
# 38        SesamCore_buckling_panel_Pl92_2__to__Pl92_8_  1570.000
# 180   SesamCore_buckling_panel_Pl759_17__to__Pl759_20_  1540.000
# 30      SesamCore_buckling_panel_Pl477_7__to__Pl477_1_  1490.000
# 653     SesamCore_buckling_panel_Pl19_29__to__Pl19_32_  1460.000
# 638   SesamCore_buckling_panel_Pl283_21__to__Pl283_24_  1450.000
# 484   SesamCore_buckling_panel_Pl759_13__to__Pl759_16_  1400.000
# 413   SesamCore_buckling_panel_Pl100_26__to__Pl100_25_  1380.000
# 211       SesamCore_buckling_panel_Pl19_5__to__Pl19_8_  1380.000
# 527     SesamCore_buckling_panel_Pl823_1__to__Pl823_7_  1310.000
# 145  SesamCore_buckling_panel_Pl482_Pl563_4__to__Pl...  1310.000
# 167     SesamCore_buckling_panel_Pl277_8__to__Pl277_5_  1300.000
# 296       SesamCore_buckling_panel_Pl97_4__to__Pl97_1_  1250.000
# 239   SesamCore_buckling_panel_Pl768_10__to__Pl768_16_  1200.000
# 240    SesamCore_buckling_panel_Pl900_16__to__Pl900_4_  1190.000
# 347    SesamCore_buckling_panel_Pl904_3__to__Pl904_15_  1190.000
# 694     SesamCore_buckling_panel_Pl823_2__to__Pl823_8_  1180.000
# 529   SesamCore_buckling_panel_Pl764_46__to__Pl764_40_  1170.000
# 207  SesamCore_buckling_panel_Pl486_31__to__Pl448_P...  1170.000
# 292   SesamCore_buckling_panel_Pl462_24__to__Pl462_21_  1130.000
# 39      SesamCore_buckling_panel_Pl916_1__to__Pl916_2_  1130.000
# 110    SesamCore_buckling_panel_Pl283_9__to__Pl283_12_  1120.000
# 388   SesamCore_buckling_panel_Pl764_56__to__Pl764_50_  1110.000
# 187         SesamCore_buckling_panel_Pl2_4__to__Pl2_1_  1090.000
# 75    SesamCore_buckling_panel_Pl480_28__to__Pl480_25_  1020.000
# 238  SesamCore_buckling_panel_Pl53450_40__to__Pl534...  1020.000
# 517    SesamCore_buckling_panel_Pl277_12__to__Pl277_9_  1020.000
# 192  SesamCore_buckling_panel_Pl472_Pl564_1__to__Pl...   992.000
# 710   SesamCore_buckling_panel_Pl759_29__to__Pl759_32_   975.000
# 343    SesamCore_buckling_panel_Pl759_9__to__Pl759_12_   971.000
# 696   SesamCore_buckling_panel_Side_o_4__to__Side_o_1_   952.000
# 169  SesamCore_buckling_panel_Pl6342_51__to__Pl6342...   942.000
# 652     SesamCore_buckling_panel_Pl19_13__to__Pl19_16_   933.000
# 535   SesamCore_buckling_panel_Pl277_28__to__Pl277_25_   929.000
# 418    SesamCore_buckling_panel_Pl905_19__to__Pl905_6_   919.000
# 628       SesamCore_buckling_panel_Pl19_1__to__Pl19_4_   903.000
# 541   SesamCore_buckling_panel_Pl283_33__to__Pl283_36_   903.000
# 277     SesamCore_buckling_panel_Pl462_8__to__Pl462_5_   892.000
# 661    SesamCore_buckling_panel_Pl764_11__to__Pl764_5_   865.000
# 216     SesamCore_buckling_panel_Pl19_41__to__Pl19_44_   827.000
# 533       SesamCore_buckling_panel_Pl2_32__to__Pl2_29_   813.000
# 170  SesamCore_buckling_panel_Pl415_Pl873_Pl879_Pl9...   811.000
# 129  SesamCore_buckling_panel_Pl970_4__to__Pl540_Pl...   803.000
# 334     SesamCore_buckling_panel_Pl233_4__to__Pl233_2_   795.000
# 542   SesamCore_buckling_panel_Pl480_20__to__Pl480_17_   795.000
# 457   SesamCore_buckling_panel_Pl480_24__to__Pl480_21_   790.000
# 714  SesamCore_buckling_panel_Pl504_Pl689_4__to__Pl...   785.000
# 3     SesamCore_buckling_panel_Pl480_32__to__Pl480_29_   781.000
# 371   SesamCore_buckling_panel_Pl277_48__to__Pl277_45_   781.000
# 243   SesamCore_buckling_panel_Pl759_33__to__Pl759_36_   771.000
# 668  SesamCore_buckling_panel_Pl231_Pl443_Pl489_Pl4...   764.000
# 464     SesamCore_buckling_panel_Pl535_1__to__Pl535_7_   755.000
# 545     SesamCore_buckling_panel_Pl487_2__to__Pl487_1_   752.000
# 574     SesamCore_buckling_panel_Pl439_4__to__Pl439_1_   752.000
# 221    SesamCore_buckling_panel_Pl900_13__to__Pl900_1_   745.000
# 47      SesamCore_buckling_panel_Pl537_7__to__Pl537_1_   740.000
# 105     SesamCore_buckling_panel_Pl814_1__to__Pl814_4_   731.000
# 523  SesamCore_buckling_panel_Pl518_Pl627_1__to__Pl...   731.000
# 600  SesamCore_buckling_panel_Pl19_Pl283_1__to__Pl1...   719.000
# 56   SesamCore_buckling_panel_Pl3006_9__to__Pl3006_10_   715.000
# 559   SesamCore_buckling_panel_Pl502_18__to__Pl502_17_   704.000
# 269   SesamCore_buckling_panel_Pl277_20__to__Pl277_17_   704.000
# 250   SesamCore_buckling_panel_Pl277_44__to__Pl277_41_   694.000
# 584      SesamCore_buckling_panel_Pl93_2__to__Pl93_11_   694.000
# 677       SesamCore_buckling_panel_Pl39_1__to__Pl39_4_   678.000
# 205     SesamCore_buckling_panel_Pl19_37__to__Pl19_40_   670.000
# 514     SesamCore_buckling_panel_Pl455_4__to__Pl455_2_   668.000
# 171     SesamCore_buckling_panel_Pl503_8__to__Pl503_7_   662.000
# 531     SesamCore_buckling_panel_Pl896_3__to__Pl896_1_   654.000
# 658       SesamCore_buckling_panel_Pl40_1__to__Pl40_4_   645.000
# ...
# 644   Equation 6.84   DLC003   3.6
# 290   Equation 6.75   DLC001   4.0
# 380   Equation 6.75   DLC003   3.5
# 572   Equation 6.72   DLC001   3.6
# 500   Equation 6.84   DLC002   3.8
# 261   Equation 6.72   DLC001   3.4
# 488   Equation 6.75   DLC001   4.0
# 218   Equation 6.75   DLC001   3.5
# 445   Equation 6.72   DLC002   3.2
# 86    Equation 6.73   DLC001   3.2
# 685   Equation 6.84   DLC003   3.4
# 537   Equation 6.72   DLC002   3.6
# 94    Equation 6.75   DLC002   3.2
# 641   Equation 6.72   DLC002   3.9
# 123   Equation 6.73   DLC003   3.5
# 326   Equation 6.72   DLC001   3.7
# 265   Equation 6.84   DLC003   4.0
# 655   Equation 6.73   DLC001   3.5
# 9     Equation 6.75   DLC002   3.2
# 607   Equation 6.72   DLC001   3.2
# 209   Equation 6.73   DLC001   3.5
# 415   Equation 6.75   DLC002   3.4
# 229   Equation 6.75   DLC003   3.5
# 344   Equation 6.74   DLC003   3.2
# 387   Equation 6.72   DLC003   3.5
# 442   Equation 6.73   DLC001   3.3
# 203   Equation 6.75   DLC001   3.8
# 234   Equation 6.72   DLC003   3.3
# 687   Equation 6.72   DLC003   3.5
# 589   Equation 6.72   DLC003   4.0
# 601   Equation 6.75   DLC002   3.7
# 33    Equation 6.72   DLC001   3.5
# 42    Equation 6.75   DLC003   3.2
# 664   Equation 6.75   DLC002   3.8
# 507   Equation 6.73   DLC002   4.0
# 176   Equation 6.73   DLC001   4.0
# 670   Equation 6.75   DLC003   3.5
# 345   Equation 6.73   DLC002   3.7
# 391   Equation 6.72   DLC002   3.2
# 635   Equation 6.75   DLC001   3.9
# 430   Equation 6.73   DLC001   3.5
# 633   Equation 6.75   DLC003   4.0
# 356   Equation 6.75   DLC003   4.0
# 454   Equation 6.73   DLC003   3.2
# 204   Equation 6.75   DLC001   3.5
# 118   Equation 6.84   DLC001   3.8
# 502   Equation 6.84   DLC003   3.2
# 35    Equation 6.75   DLC003   3.2
# 606   Equation 6.75   DLC002   3.3
# 540   Equation 6.84   DLC002   3.9
# 43    Equation 6.75   DLC002   3.6
# 183   Equation 6.72   DLC002   3.2
# 568   Equation 6.73   DLC003   3.5
# 107   Equation 6.84   DLC003   3.5
# 235   Equation 6.75   DLC002   3.8
# 206   Equation 6.72   DLC001   3.2
# 222   Equation 6.73   DLC003   3.4
# 467   Equation 6.75   DLC002   3.5
# 252   Equation 6.72   DLC003   3.5
# 461   Equation 6.73   DLC001   3.8
# 197   Equation 6.72   DLC003   3.5
# 330   Equation 6.72   DLC002   3.9
# 615   Equation 6.72   DLC001   4.0
# 54    Equation 6.72   DLC002   3.2
# 362   Equation 6.72   DLC001   3.5
# 477   Equation 6.73   DLC003   4.0
# 346   Equation 6.72   DLC001   3.3
# 447   Equation 6.73   DLC001   4.0
# 493   Equation 6.75   DLC002   3.5
# 561   Equation 6.72   DLC001   3.5
# 126   Equation 6.75   DLC001   3.5
# 172   Equation 6.72   DLC001   3.9
# 79    Equation 6.84   DLC001   3.2
# 2     Equation 6.73   DLC003   3.3
# 440   Equation 6.73   DLC003   3.7
# 288   Equation 6.72   DLC003   3.5
# 381   Equation 6.72   DLC002   3.2
# 342   Equation 6.74   DLC001   3.5
# 128   Equation 6.73   DLC003   3.6
# 436   Equation 6.84   DLC002   3.2
# 278   Equation 6.73   DLC001   3.5
# 558   Equation 6.73   DLC002   4.0
# 433   Equation 6.84   DLC001   3.5
# 122   Equation 6.75   DLC002   4.0
# 471   Equation 6.73   DLC002   3.5
# 225   Equation 6.73   DLC001   3.5
# 427   Equation 6.73   DLC001   3.5
# 50    Equation 6.75   DLC002   3.6
# 680   Equation 6.73   DLC001   3.5
# 175   Equation 6.72   DLC001   3.5
# 674   Equation 6.73   DLC003   3.5
# 284   Equation 6.74   DLC003   3.6
# 142   Equation 6.84   DLC003   3.5
# 275   Equation 6.84   DLC001   3.8
# 194   Equation 6.73   DLC001   3.5
# 258   Equation 6.72   DLC001   3.7
# 18    Equation 6.73   DLC001   3.5
# 199   Equation 6.73   DLC003   4.0
# 214   Equation 6.72   DLC002   3.5
# 143   Equation 6.73   DLC001   3.5
# 27    Equation 6.72   DLC002   3.2
# 124   Equation 6.75   DLC003   3.2
# 215   Equation 6.84   DLC003   3.2
# 443   Equation 6.75   DLC001   3.2
# 361   Equation 6.72   DLC002   3.2
# 377   Equation 6.75   DLC001   3.8
# 31    Equation 6.72   DLC001   3.2
# 553   Equation 6.72   DLC001   3.9
# 637   Equation 6.72   DLC001   3.9
# 525   Equation 6.73   DLC001   3.5
# 571   Equation 6.75   DLC002   3.2
# 279   Equation 6.73   DLC001   3.5
# 408   Equation 6.73   DLC001   3.5
# 384   Equation 6.72   DLC001   3.5
# 659   Equation 6.75   DLC001   3.5
# 422   Equation 6.72   DLC003   3.9
# 650   Equation 6.73   DLC001   3.5
# 280   Equation 6.84   DLC002   3.5
# 486   Equation 6.75   DLC002   4.0
# 583   Equation 6.73   DLC001   4.0
# 338   Equation 6.73   DLC001   4.0
# 444   Equation 6.75   DLC003   3.5
# 409   Equation 6.84   DLC002   3.9
# 256   Equation 6.73   DLC003   3.5
# 702   Equation 6.73   DLC002   4.0
# 554   Equation 6.84   DLC003   3.6
# 195   Equation 6.75   DLC001   3.6
# 564   Equation 6.75   DLC001   3.5
# 654   Equation 6.72   DLC003   3.7
# 360   Equation 6.72   DLC003   3.5
# 196   Equation 6.72   DLC002   3.2
# 420   Equation 6.73   DLC001   3.5
# 74    Equation 6.72   DLC003   4.0
# 21    Equation 6.73   DLC002   3.7
# 20    Equation 6.74   DLC001   3.5
# 270   Equation 6.73   DLC001   3.5
# 399   Equation 6.84   DLC001   3.7
# 153   Equation 6.84   DLC001   3.7
# 563   Equation 6.72   DLC002   3.2
# 148   Equation 6.84   DLC002   3.3
# 431   Equation 6.75   DLC002   3.6
# 151   Equation 6.84   DLC001   3.2
# 378   Equation 6.75   DLC001   3.5
# 241   Equation 6.72   DLC001   3.5
# 672   Equation 6.72   DLC001   3.5
# 536   Equation 6.73   DLC002   3.2
# 198   Equation 6.73   DLC002   3.4
# 715   Equation 6.72   DLC002   3.4
# 683   Equation 6.75   DLC003   3.5
# 49    Equation 6.72   DLC003   4.0
# 246   Equation 6.75   DLC003   3.6
# 689   Equation 6.84   DLC001   3.3
# 311   Equation 6.72   DLC003   3.5
# 660   Equation 6.84   DLC001   3.5
# 312   Equation 6.75   DLC001   3.5
# 10    Equation 6.72   DLC001   3.3
# 101   Equation 6.72   DLC002   3.9
# 272   Equation 6.75   DLC002   3.3
# 95    Equation 6.84   DLC002   3.6
# 318   Equation 6.75   DLC003   3.4
# 96    Equation 6.84   DLC001   3.5
# 495   Equation 6.73   DLC001   3.7
# 114   Equation 6.72   DLC001   3.5
# 699   Equation 6.72   DLC001   4.0
# 220   Equation 6.75   DLC001   3.5
# 373   Equation 6.73   DLC003   3.5
# 138   Equation 6.84   DLC002   3.4
# 546   Equation 6.75   DLC003   3.5
# 55    Equation 6.75   DLC002   3.7
# 359   Equation 6.73   DLC002   3.3
# 501   Equation 6.75   DLC001   3.5
# 515   Equation 6.75   DLC001   3.6
# 552   Equation 6.72   DLC002   3.8
# 132   Equation 6.73   DLC002   3.9
# 621   Equation 6.84   DLC003   3.5
# 618   Equation 6.72   DLC001   3.3
# 706   Equation 6.75   DLC003   3.5
# 594   Equation 6.84   DLC002   3.6
# 293   Equation 6.72   DLC002   3.7
# 404   Equation 6.75   DLC002   3.5
# 560   Equation 6.84   DLC003   3.5
# 602   Equation 6.84   DLC003   3.9
# 259   Equation 6.75   DLC002   3.2
# 285   Equation 6.75   DLC002   3.7
# 310   Equation 6.72   DLC003   3.2
# 58    Equation 6.72   DLC002   3.8
# 522   Equation 6.84   DLC002   3.5
# 435   Equation 6.84   DLC002   3.2
# 57    Equation 6.73   DLC003   3.5
# 44    Equation 6.72   DLC002   3.7
# 456   Equation 6.72   DLC003   3.5
# 309   Equation 6.73   DLC001   3.5
# 681   Equation 6.75   DLC002   3.6
# 509   Equation 6.72   DLC003   3.5
# 512   Equation 6.84   DLC002   3.5
# 354   Equation 6.84   DLC001   3.5
# 374   Equation 6.73   DLC003   3.5
# 393   Equation 6.73   DLC003   3.5
# 164   Equation 6.72   DLC001   3.5
# 168   Equation 6.72   DLC002   3.2
# 429   Equation 6.72   DLC001   3.5
# 115   Equation 6.75   DLC001   3.4
# 14    Equation 6.84   DLC003   3.2
# 579   Equation 6.84   DLC003   3.8
# 305   Equation 6.75   DLC001   3.5
# 492   Equation 6.73   DLC002   3.3
# 304   Equation 6.72   DLC001   3.3
# 555   Equation 6.72   DLC003   3.5
# 547   Equation 6.84   DLC003   3.5
# 437   Equation 6.84   DLC001   3.5
# 605   Equation 6.72   DLC002   3.7
# 390   Equation 6.73   DLC003   3.5
# 340   Equation 6.72   DLC003   3.5
# 665   Equation 6.75   DLC003   3.5
# 113   Equation 6.73   DLC002   3.6
# 452   Equation 6.73   DLC003   3.9
# 87    Equation 6.72   DLC002   4.0
# 711   Equation 6.72   DLC002   4.0
# 268   Equation 6.75   DLC001   3.5
# 549   Equation 6.75   DLC003   3.7
# 406   Equation 6.73   DLC003   3.5
# 358   Equation 6.84   DLC002   3.2
# 189   Equation 6.73   DLC001   3.7
# 130   Equation 6.84   DLC001   3.5
# 51    Equation 6.84   DLC001   3.7
# 598   Equation 6.84   DLC003   3.5
# 497   Equation 6.75   DLC001   3.5
# 448   Equation 6.84   DLC003   3.8
# 352   Equation 6.84   DLC001   3.5
# 327   Equation 6.72   DLC001   3.2
# 521   Equation 6.74   DLC002   3.4
# 596   Equation 6.84   DLC001   4.0
# 462   Equation 6.84   DLC002   3.8
# 306   Equation 6.84   DLC001   3.5
# 350   Equation 6.72   DLC002   3.7
# 705   Equation 6.84   DLC003   3.5
# 397   Equation 6.72   DLC003   3.2
# 582   Equation 6.75   DLC003   3.4
# 177   Equation 6.75   DLC002   3.2
# 651   Equation 6.73   DLC002   3.9
# 295   Equation 6.74   DLC002   3.4
# 624   Equation 6.84   DLC003   3.2
# 286   Equation 6.72   DLC001   4.0
# 228   Equation 6.72   DLC003   3.5
# 37    Equation 6.73   DLC003   3.5
# 121   Equation 6.84   DLC003   3.5
# 592   Equation 6.72   DLC003   3.3
# 191   Equation 6.72   DLC003   3.4
# 630   Equation 6.84   DLC003   4.0
# 526   Equation 6.84   DLC002   3.2
# 557   Equation 6.72   DLC003   3.8
# 159   Equation 6.72   DLC003   3.5
# 419   Equation 6.84   DLC003   3.6
# 496   Equation 6.73   DLC001   3.5
# 182   Equation 6.84   DLC001   3.5
# 487   Equation 6.84   DLC001   3.3
# 379   Equation 6.73   DLC001   3.5
# 147   Equation 6.84   DLC002   3.8
# 692   Equation 6.75   DLC003   3.5
# 116   Equation 6.73   DLC003   3.5
# 120   Equation 6.72   DLC003   3.8
# 679   Equation 6.73   DLC001   3.5
# 636   Equation 6.73   DLC002   3.6
# 483   Equation 6.73   DLC002   4.0
# 316   Equation 6.84   DLC002   3.4
# 700   Equation 6.84   DLC001   3.8
# 88    Equation 6.84   DLC003   3.5
# 226   Equation 6.73   DLC001   3.5
# 405   Equation 6.73   DLC001   3.7
# 24    Equation 6.72   DLC002   3.8
# 709   Equation 6.73   DLC003   3.5
# 298   Equation 6.84   DLC003   3.3
# 301   Equation 6.73   DLC002   3.7
# 576   Equation 6.72   DLC003   3.5
# 595   Equation 6.73   DLC002   4.0
# 289   Equation 6.73   DLC001   3.7
# 363   Equation 6.72   DLC002   3.9
# 181   Equation 6.73   DLC003   4.0
# 102   Equation 6.73   DLC003   3.5
# 686   Equation 6.84   DLC002   3.3
# 489   Equation 6.72   DLC001   3.6
# 26    Equation 6.73   DLC003   3.5
# 78    Equation 6.84   DLC001   3.5
# 317   Equation 6.75   DLC001   3.5
# 131   Equation 6.84   DLC002   3.6
# 76    Equation 6.75   DLC002   3.4
# 604   Equation 6.75   DLC003   3.2
# 610   Equation 6.75   DLC003   3.5
# 236   Equation 6.75   DLC003   3.8
# 36    Equation 6.72   DLC001   3.5
# 473   Equation 6.84   DLC003   3.5
# 472   Equation 6.73   DLC003   3.5
# 61    Equation 6.84   DLC003   3.5
# 150   Equation 6.73   DLC001   3.8
# 200   Equation 6.84   DLC001   3.5
# 468   Equation 6.84   DLC001   3.4
# 156   Equation 6.84   DLC003   3.5
# 446   Equation 6.73   DLC001   3.5
# 357   Equation 6.84   DLC003   3.5
# 370   Equation 6.75   DLC001   3.5
# 386   Equation 6.84   DLC002   3.3
# 426   Equation 6.84   DLC003   3.5
# 673   Equation 6.75   DLC003   3.4
# 40    Equation 6.84   DLC001   4.0
# 103   Equation 6.72   DLC003   3.5
# 466   Equation 6.72   DLC003   3.5
# 294   Equation 6.72   DLC002   3.5
# 656   Equation 6.84   DLC001   3.8
# 425   Equation 6.75   DLC003   3.5
# 551   Equation 6.72   DLC001   3.5
# 688   Equation 6.72   DLC003   3.9
# 499   Equation 6.73   DLC003   3.8
# 450   Equation 6.73   DLC003   3.5
# 412   Equation 6.75   DLC001   3.8
# 417   Equation 6.73   DLC003   3.5
# 611   Equation 6.84   DLC003   3.5
# 481   Equation 6.84   DLC003   3.5
# 713   Equation 6.84   DLC002   3.7
# 160   Equation 6.73   DLC001   3.5
# 513   Equation 6.73   DLC001   4.0
# 82    Equation 6.74   DLC001   3.5
# 678   Equation 6.84   DLC003   3.4
# 45    Equation 6.75   DLC001   3.5
# 64    Equation 6.84   DLC003   3.5
# 510   Equation 6.84   DLC002   3.7
# 627   Equation 6.72   DLC002   3.5
# 70    Equation 6.74   DLC001   3.5
# 141   Equation 6.75   DLC001   3.5
# 135   Equation 6.75   DLC003   3.5
# 516   Equation 6.72   DLC003   3.8
# 260   Equation 6.84   DLC003   4.0
# 232   Equation 6.84   DLC003   3.6
# 117   Equation 6.75   DLC001   3.5
# 111   Equation 6.72   DLC003   3.5
# 647   Equation 6.73   DLC001   3.5
# 283   Equation 6.73   DLC001   3.5
# 434   Equation 6.72   DLC001   3.5
# 59    Equation 6.73   DLC001   4.0
# 19    Equation 6.84   DLC003   3.5
# 432   Equation 6.72   DLC002   3.7
# 237   Equation 6.84   DLC003   3.5
# 90    Equation 6.73   DLC001   3.5
# 4     Equation 6.73   DLC003   3.5
# 617   Equation 6.84   DLC001   3.5
# 416   Equation 6.72   DLC003   3.3
# 368   Equation 6.84   DLC003   3.5
# 581   Equation 6.75   DLC001   3.5
# 414   Equation 6.73   DLC003   3.9
# 333   Equation 6.72   DLC001   3.5
# 300   Equation 6.72   DLC001   3.5
# 23    Equation 6.73   DLC001   3.5
# 562   Equation 6.84   DLC003   4.0
# 1     Equation 6.72   DLC003   3.5
# 608   Equation 6.72   DLC003   3.5
# 640   Equation 6.73   DLC001   3.2
# 575   Equation 6.72   DLC003   3.3
# 520   Equation 6.73   DLC001   3.9
# 80    Equation 6.84   DLC001   3.4
# 534   Equation 6.84   DLC001   3.5
# 108   Equation 6.84   DLC002   3.9
# 634   Equation 6.75   DLC003   3.5
# 97    Equation 6.74   DLC001   3.5
# 458   Equation 6.74   DLC002   3.9
# 599   Equation 6.84   DLC002   3.6
# 163   Equation 6.72   DLC003   3.9
# 91    Equation 6.73   DLC001   3.5
# 662   Equation 6.75   DLC002   4.0
# 7     Equation 6.84   DLC003   4.0
# 52    Equation 6.73   DLC001   3.4
# 60    Equation 6.73   DLC002   3.7
# 339   Equation 6.72   DLC001   4.0
# 411   Equation 6.72   DLC002   3.2
# 184   Equation 6.84   DLC001   3.5
# 620   Equation 6.84   DLC003   3.6
# 89    Equation 6.84   DLC003   4.0
# 319   Equation 6.73   DLC002   3.6
# 193   Equation 6.84   DLC003   3.5
# 217   Equation 6.72   DLC001   3.3
# 663   Equation 6.72   DLC001   3.5
# 441   Equation 6.72   DLC003   3.5
# 186   Equation 6.73   DLC001   3.2
# 491   Equation 6.84   DLC003   3.9
# 428   Equation 6.84   DLC003   3.5
# 625   Equation 6.72   DLC001   3.5
# 703   Equation 6.73   DLC001   3.5
# 48    Equation 6.73   DLC001   3.5
# 212   Equation 6.84   DLC003   3.5
# 351   Equation 6.72   DLC002   3.6
# 410   Equation 6.84   DLC002   3.2
# 349   Equation 6.75   DLC002   3.7
# 626   Equation 6.73   DLC002   4.0
# 83    Equation 6.73   DLC001   3.5
# 140   Equation 6.72   DLC003   3.5
# 308   Equation 6.73   DLC002   3.5
# 41    Equation 6.84   DLC001   4.0
# 669   Equation 6.72   DLC001   3.5
# 329   Equation 6.72   DLC002   3.8
# 567   Equation 6.84   DLC003   3.2
# 34    Equation 6.84   DLC003   3.5
# 382   Equation 6.84   DLC002   3.2
# 697   Equation 6.73   DLC003   3.8
# 248   Equation 6.84   DLC001   4.0
# 498   Equation 6.84   DLC003   3.5
# 485   Equation 6.84   DLC003   3.2
# 565   Equation 6.84   DLC002   3.9
# 591   Equation 6.84   DLC002   3.2
# 629   Equation 6.84   DLC003   3.5
# 281   Equation 6.83   DLC003   3.5
# 518   Equation 6.84   DLC001   4.0
# 73    Equation 6.83   DLC001   3.5
# 478   Equation 6.75   DLC001   3.3
# 609   Equation 6.84   DLC003   3.5
# 17    Equation 6.84   DLC002   3.2
# 407   Equation 6.84   DLC001   3.5
# 257   Equation 6.72   DLC001   3.5
# 538   Equation 6.73   DLC003   3.6
# 550   Equation 6.73   DLC001   3.5
# 614   Equation 6.73   DLC001   3.7
# 389   Equation 6.72   DLC001   3.5
# 671   Equation 6.84   DLC001   3.5
# 383   Equation 6.84   DLC001   3.6
# 469   Equation 6.83   DLC001   3.4
# 548   Equation 6.84   DLC001   3.9
# 174   Equation 6.83   DLC003   4.0
# 307   Equation 6.84   DLC002   3.7
# 337   Equation 6.84   DLC001   3.5
# 53    Equation 6.84   DLC001   3.5
# 161   Equation 6.84   DLC001   3.5
# 125   Equation 6.83   DLC001   3.5
# 622   Equation 6.72   DLC001   3.5
# 25     Equation 8.1   DLC001   3.2
# 475    Equation 8.1   DLC001   3.2
